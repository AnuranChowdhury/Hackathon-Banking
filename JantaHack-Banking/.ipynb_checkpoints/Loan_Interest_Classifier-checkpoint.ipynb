# %% [markdown]
# ### 1. Data Knowledge

# %% [markdown]
# #### Data dictonary
#        Loan_ID : A unique id for the loan.
#        Loan_Amount_Requested : The listed amount of the loan applied for by the borrower.
#        Length_Employed : Employment length in years
#        Home_Owner : The home ownership status provided by the borrower during registration. Values are: Rent, Own, Mortgage, Other.
#        Annual_Income : The annual income provided by the borrower during registration.
#        Income_Verified : Indicates if income was verified, not verified, or if the income source was verified
#        Purpose_Of_Loan : A category provided by the borrower for the loan request.
#        Debt_To_Income : A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested loan, divided by the borrower’s self-reported monthly income.
#        Inquiries_Last_6Mo : The number of inquiries by creditors during the past 6 months.
#        Months_Since_Deliquency : The number of months since the borrower's last delinquency.
#        Number_Open_Accounts : The number of open credit lines in the borrower's credit file.
#        Total_Accounts : The total number of credit lines currently in the borrower's credit file
#        Gender : Gender
#        Interest_Rate : Target Variable: Interest Rate category (1/2/3) of the loan application

# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Input

# %%
loan_df = pd.read_csv('train_fNxu4vz.csv')

# %%
## Getting the first 5 rows
loan_df.head()
# Out:
#     Loan_ID Loan_Amount_Requested Length_Employed Home_Owner  Annual_Income  \
# 0  10000001                 7,000        < 1 year       Rent        68000.0
# 1  10000002                30,000         4 years   Mortgage            NaN
# 2  10000003                24,725         7 years   Mortgage        75566.4
# 3  10000004                16,000        < 1 year        NaN        56160.0
# 4  10000005                17,000         8 years        Own        96000.0
#
#             Income_Verified     Purpose_Of_Loan  Debt_To_Income  \
# 0              not verified                 car           18.37
# 1         VERIFIED - income  debt_consolidation           14.93
# 2  VERIFIED - income source  debt_consolidation           15.88
# 3  VERIFIED - income source  debt_consolidation           14.34
# 4  VERIFIED - income source  debt_consolidation           22.17
#
#    Inquiries_Last_6Mo  Months_Since_Deliquency  Number_Open_Accounts  \
# 0                   0                      NaN                     9
# 1                   0                     17.0                    12
# 2                   0                      NaN                    12
# 3                   3                      NaN                    16
# 4                   1                      NaN                    19
#
#    Total_Accounts  Gender  Interest_Rate
# 0              14  Female              1
# 1              24  Female              3
# 2              16    Male              3
# 3              22    Male              3
# 4              30  Female              1

# %%
## Shape of the training data
loan_df.shape
# Out:
# (164309, 14)

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164309 entries, 0 to 164308
# Data columns (total 14 columns):
# Loan_ID                    164309 non-null int64
# Loan_Amount_Requested      164309 non-null object
# Length_Employed            156938 non-null object
# Home_Owner                 138960 non-null object
# Annual_Income              139207 non-null float64
# Income_Verified            164309 non-null object
# Purpose_Of_Loan            164309 non-null object
# Debt_To_Income             164309 non-null float64
# Inquiries_Last_6Mo         164309 non-null int64
# Months_Since_Deliquency    75930 non-null float64
# Number_Open_Accounts       164309 non-null int64
# Total_Accounts             164309 non-null int64
# Gender                     164309 non-null object
# Interest_Rate              164309 non-null int64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 17.6+ MB

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID                        0
# Loan_Amount_Requested          0
# Length_Employed             7371
# Home_Owner                 25349
# Annual_Income              25102
# Income_Verified                0
# Purpose_Of_Loan                0
# Debt_To_Income                 0
# Inquiries_Last_6Mo             0
# Months_Since_Deliquency    88379
# Number_Open_Accounts           0
# Total_Accounts                 0
# Gender                         0
# Interest_Rate                  0
# dtype: int64

# %% [markdown]
# #### Imputing null values

# %%
loan_df['Months_Since_Deliquency'].plot(kind = 'density')

# %%
loan_df['Months_Since_Deliquency_zero'] = loan_df['Months_Since_Deliquency'].fillna(0.0)

# %%
loan_df['Months_Since_Deliquency_zero'].plot(kind = 'density')

# %%
loan_df['Months_Since_Deliquency'].describe(percentiles=[0.05,0.25,0.35,0.5,0.75,0.90,0.95])
# Out:
# count    75930.000000
# mean        34.229356
# std         21.761180
# min          0.000000
# 5%           5.000000
# 25%         16.000000
# 35%         21.000000
# 50%         31.000000
# 75%         50.000000
# 90%         68.000000
# 95%         74.000000
# max        180.000000
# Name: Months_Since_Deliquency, dtype: float64

# %%
##Observation for loan_df['Months_Since_Deliquency']
    #1.Value is distributed
    #2.Imputing it with mean or median could add bias
    #3.Strategy to impute values is generating randon numbers between 25 and 75 percentile of existing values
import math
import random
def imputeRandomValue(x):
    if math.isnan(x):
        return float(random.randint(10,60))
    else:
        return x

# %%
loan_df['Months_Since_Deliquency_rand1'] = loan_df['Months_Since_Deliquency'].apply(lambda x : imputeRandomValue(x))

# %%
loan_df['Months_Since_Deliquency_rand2'] = loan_df['Months_Since_Deliquency'].apply(lambda x : imputeRandomValue(x))

# %%
loan_df['Months_Since_Deliquency_rand3'] = loan_df['Months_Since_Deliquency'].apply(lambda x : imputeRandomValue(x))

# %%
loan_df[['Months_Since_Deliquency_zero','Months_Since_Deliquency','Months_Since_Deliquency_rand1','Months_Since_Deliquency_rand2','Months_Since_Deliquency_rand3']].describe().T
# Out:
#                                   count       mean        std  min   25%  \
# Months_Since_Deliquency_zero   164309.0  15.817971  22.584642  0.0   0.0
# Months_Since_Deliquency         75930.0  34.229356  21.761180  0.0  16.0
# Months_Since_Deliquency_rand1  164309.0  34.657444  18.316154  0.0  19.0
# Months_Since_Deliquency_rand2  164309.0  34.679731  18.322795  0.0  19.0
# Months_Since_Deliquency_rand3  164309.0  34.586048  18.302294  0.0  19.0
#
#                                 50%   75%    max
# Months_Since_Deliquency_zero    0.0  28.0  180.0
# Months_Since_Deliquency        31.0  50.0  180.0
# Months_Since_Deliquency_rand1  33.0  48.0  180.0
# Months_Since_Deliquency_rand2  34.0  48.0  180.0
# Months_Since_Deliquency_rand3  33.0  48.0  180.0

# %%
#From above we see Months_Since_Deliquency_rand1 is more closer to the actual data, so replacing main column with this value
loan_df['Months_Since_Deliquency'] = loan_df['Months_Since_Deliquency_rand1']

# %%
loan_df.head(10)
# Out:
#     Loan_ID Loan_Amount_Requested Length_Employed Home_Owner  Annual_Income  \
# 0  10000001                 7,000        < 1 year       Rent        68000.0
# 1  10000002                30,000         4 years   Mortgage            NaN
# 2  10000003                24,725         7 years   Mortgage        75566.4
# 3  10000004                16,000        < 1 year        NaN        56160.0
# 4  10000005                17,000         8 years        Own        96000.0
# 5  10000006                 4,500         2 years       Rent        30000.0
# 6  10000007                18,075         4 years       Rent        85000.0
# 7  10000008                15,000        < 1 year       Rent       115000.0
# 8  10000009                 6,300       10+ years       Rent            NaN
# 9  10000010                30,000       10+ years        Own       163000.0
#
#             Income_Verified     Purpose_Of_Loan  Debt_To_Income  \
# 0              not verified                 car           18.37
# 1         VERIFIED - income  debt_consolidation           14.93
# 2  VERIFIED - income source  debt_consolidation           15.88
# 3  VERIFIED - income source  debt_consolidation           14.34
# 4  VERIFIED - income source  debt_consolidation           22.17
# 5  VERIFIED - income source         credit_card           10.88
# 6         VERIFIED - income  debt_consolidation            5.65
# 7         VERIFIED - income  debt_consolidation            7.97
# 8              not verified  debt_consolidation           16.12
# 9         VERIFIED - income  debt_consolidation           11.13
#
#    Inquiries_Last_6Mo  Months_Since_Deliquency  Number_Open_Accounts  \
# 0                   0                     12.0                     9
# 1                   0                     17.0                    12
# 2                   0                     47.0                    12
# 3                   3                     48.0                    16
# 4                   1                     26.0                    19
# 5                   1                     38.0                    12
# 6                   0                     23.0                     9
# 7                   1                     16.0                    25
# 8                   3                     54.0                     8
# 9                   0                     14.0                    24
#
#    Total_Accounts  Gender  Interest_Rate  Months_Since_Deliquency_zero  \
# 0              14  Female              1                           0.0
# 1              24  Female              3                          17.0
# 2              16    Male              3                           0.0
# 3              22    Male              3                           0.0
# 4              30  Female              1                           0.0
# 5              15    Male              3                           0.0
# 6              12    Male              3                           0.0
# 7              31  Female              2                          16.0
# 8               9  Female              3                           0.0
# 9              43    Male              1                           0.0
#
#    Months_Since_Deliquency_rand1  Months_Since_Deliquency_rand2  \
# 0                           12.0                           46.0
# 1                           17.0                           17.0
# 2                           47.0                           33.0
# 3                           48.0                           21.0
# 4                           26.0                           27.0
# 5                           38.0                           52.0
# 6                           23.0                           43.0
# 7                           16.0                           16.0
# 8                           54.0                           13.0
# 9                           14.0                           14.0
#
#    Months_Since_Deliquency_rand3
# 0                           26.0
# 1                           17.0
# 2                           59.0
# 3                           59.0
# 4                           41.0
# 5                           54.0
# 6                           10.0
# 7                           16.0
# 8                           18.0
# 9                           52.0

# %%
##Deleting the new generated irrelavant columns
loan_df.drop(columns=['Months_Since_Deliquency_rand1','Months_Since_Deliquency_rand2','Months_Since_Deliquency_rand3','Months_Since_Deliquency_zero'], axis =1, inplace=True)

# %% [markdown]
# #### Converting the non-numerical to numerical columns

# %%
loan_df.select_dtypes(include = 'object').head(22)
# Out:
#    Loan_Amount_Requested Length_Employed Home_Owner           Income_Verified  \
# 0                  7,000        < 1 year       Rent              not verified
# 1                 30,000         4 years   Mortgage         VERIFIED - income
# 2                 24,725         7 years   Mortgage  VERIFIED - income source
# 3                 16,000        < 1 year        NaN  VERIFIED - income source
# 4                 17,000         8 years        Own  VERIFIED - income source
# 5                  4,500         2 years       Rent  VERIFIED - income source
# 6                 18,075         4 years       Rent         VERIFIED - income
# 7                 15,000        < 1 year       Rent         VERIFIED - income
# 8                  6,300       10+ years       Rent              not verified
# 9                 30,000       10+ years        Own         VERIFIED - income
# 10                11,700       10+ years   Mortgage         VERIFIED - income
# 11                15,000       10+ years       Rent              not verified
# 12                 7,200       10+ years       Rent  VERIFIED - income source
# 13                15,000       10+ years   Mortgage  VERIFIED - income source
# 14                 6,700       10+ years   Mortgage  VERIFIED - income source
# 15                35,000         4 years       Rent         VERIFIED - income
# 16                20,800       10+ years   Mortgage  VERIFIED - income source
# 17                19,925       10+ years       Rent  VERIFIED - income source
# 18                25,000       10+ years       Rent         VERIFIED - income
# 19                 6,000          1 year        Own  VERIFIED - income source
# 20                 4,000       10+ years       Rent              not verified
# 21                 8,000         7 years   Mortgage              not verified
#
#        Purpose_Of_Loan  Gender
# 0                  car  Female
# 1   debt_consolidation  Female
# 2   debt_consolidation    Male
# 3   debt_consolidation    Male
# 4   debt_consolidation  Female
# 5          credit_card    Male
# 6   debt_consolidation    Male
# 7   debt_consolidation  Female
# 8   debt_consolidation  Female
# 9   debt_consolidation    Male
# 10  debt_consolidation    Male
# 11         credit_card    Male
# 12  debt_consolidation    Male
# 13  debt_consolidation    Male
# 14         credit_card    Male
# 15         credit_card  Female
# 16  debt_consolidation    Male
# 17  debt_consolidation    Male
# 18         credit_card  Female
# 19  debt_consolidation    Male
# 20         credit_card  Female
# 21    home_improvement  Female

# %%
loan_df['Income_Verified'].value_counts()
# Out:
# VERIFIED - income           59421
# VERIFIED - income source    53015
# not verified                51873
# Name: Income_Verified, dtype: int64

# %%
dummy_cols = pd.get_dummies(loan_df['Income_Verified'])

# %%
loan_df = pd.concat([loan_df,dummy_cols],axis=1)

# %%
loan_df.head()
# Out:
#     Loan_ID Loan_Amount_Requested Length_Employed Home_Owner  Annual_Income  \
# 0  10000001                 7,000        < 1 year       Rent        68000.0
# 1  10000002                30,000         4 years   Mortgage            NaN
# 2  10000003                24,725         7 years   Mortgage        75566.4
# 3  10000004                16,000        < 1 year        NaN        56160.0
# 4  10000005                17,000         8 years        Own        96000.0
#
#             Income_Verified     Purpose_Of_Loan  Debt_To_Income  \
# 0              not verified                 car           18.37
# 1         VERIFIED - income  debt_consolidation           14.93
# 2  VERIFIED - income source  debt_consolidation           15.88
# 3  VERIFIED - income source  debt_consolidation           14.34
# 4  VERIFIED - income source  debt_consolidation           22.17
#
#    Inquiries_Last_6Mo  Months_Since_Deliquency  Number_Open_Accounts  \
# 0                   0                     12.0                     9
# 1                   0                     17.0                    12
# 2                   0                     47.0                    12
# 3                   3                     48.0                    16
# 4                   1                     26.0                    19
#
#    Total_Accounts  Gender  Interest_Rate  VERIFIED - income  \
# 0              14  Female              1                  0
# 1              24  Female              3                  1
# 2              16    Male              3                  0
# 3              22    Male              3                  0
# 4              30  Female              1                  0
#
#    VERIFIED - income source  not verified
# 0                         0             1
# 1                         0             0
# 2                         1             0
# 3                         1             0
# 4                         1             0

# %%
loan_df.drop('Income_Verified',axis =1, inplace=True)

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164309 entries, 0 to 164308
# Data columns (total 16 columns):
# Loan_ID                     164309 non-null int64
# Loan_Amount_Requested       164309 non-null object
# Length_Employed             156938 non-null object
# Home_Owner                  138960 non-null object
# Annual_Income               139207 non-null float64
# Purpose_Of_Loan             164309 non-null object
# Debt_To_Income              164309 non-null float64
# Inquiries_Last_6Mo          164309 non-null int64
# Months_Since_Deliquency     164309 non-null float64
# Number_Open_Accounts        164309 non-null int64
# Total_Accounts              164309 non-null int64
# Gender                      164309 non-null object
# Interest_Rate               164309 non-null int64
# VERIFIED - income           164309 non-null uint8
# VERIFIED - income source    164309 non-null uint8
# not verified                164309 non-null uint8
# dtypes: float64(3), int64(5), object(5), uint8(3)
# memory usage: 16.8+ MB

# %%
## Converting Gender column
gender_cols = pd.get_dummies(loan_df['Gender'])
loan_df = pd.concat([loan_df, gender_cols], axis =1)
loan_df.head()
# Out:
#     Loan_ID Loan_Amount_Requested Length_Employed Home_Owner  Annual_Income  \
# 0  10000001                 7,000        < 1 year       Rent        68000.0
# 1  10000002                30,000         4 years   Mortgage            NaN
# 2  10000003                24,725         7 years   Mortgage        75566.4
# 3  10000004                16,000        < 1 year        NaN        56160.0
# 4  10000005                17,000         8 years        Own        96000.0
#
#       Purpose_Of_Loan  Debt_To_Income  Inquiries_Last_6Mo  \
# 0                 car           18.37                   0
# 1  debt_consolidation           14.93                   0
# 2  debt_consolidation           15.88                   0
# 3  debt_consolidation           14.34                   3
# 4  debt_consolidation           22.17                   1
#
#    Months_Since_Deliquency  Number_Open_Accounts  Total_Accounts  Gender  \
# 0                     12.0                     9              14  Female
# 1                     17.0                    12              24  Female
# 2                     47.0                    12              16    Male
# 3                     48.0                    16              22    Male
# 4                     26.0                    19              30  Female
#
#    Interest_Rate  VERIFIED - income  VERIFIED - income source  not verified  \
# 0              1                  0                         0             1
# 1              3                  1                         0             0
# 2              3                  0                         1             0
# 3              3                  0                         1             0
# 4              1                  0                         1             0
#
#    Female  Male
# 0       1     0
# 1       1     0
# 2       0     1
# 3       0     1
# 4       1     0

# %%
loan_df.drop('Gender',axis=1, inplace = True)

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164309 entries, 0 to 164308
# Data columns (total 17 columns):
# Loan_ID                     164309 non-null int64
# Loan_Amount_Requested       164309 non-null object
# Length_Employed             156938 non-null object
# Home_Owner                  138960 non-null object
# Annual_Income               139207 non-null float64
# Purpose_Of_Loan             164309 non-null object
# Debt_To_Income              164309 non-null float64
# Inquiries_Last_6Mo          164309 non-null int64
# Months_Since_Deliquency     164309 non-null float64
# Number_Open_Accounts        164309 non-null int64
# Total_Accounts              164309 non-null int64
# Interest_Rate               164309 non-null int64
# VERIFIED - income           164309 non-null uint8
# VERIFIED - income source    164309 non-null uint8
# not verified                164309 non-null uint8
# Female                      164309 non-null uint8
# Male                        164309 non-null uint8
# dtypes: float64(3), int64(5), object(4), uint8(5)
# memory usage: 15.8+ MB

# %%
##Converting Loan_Amount_requested
loan_df['Loan_Amount_Requested'] = loan_df['Loan_Amount_Requested'].apply(lambda x : int(x.replace(',','')))

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164309 entries, 0 to 164308
# Data columns (total 17 columns):
# Loan_ID                     164309 non-null int64
# Loan_Amount_Requested       164309 non-null int64
# Length_Employed             156938 non-null object
# Home_Owner                  138960 non-null object
# Annual_Income               139207 non-null float64
# Purpose_Of_Loan             164309 non-null object
# Debt_To_Income              164309 non-null float64
# Inquiries_Last_6Mo          164309 non-null int64
# Months_Since_Deliquency     164309 non-null float64
# Number_Open_Accounts        164309 non-null int64
# Total_Accounts              164309 non-null int64
# Interest_Rate               164309 non-null int64
# VERIFIED - income           164309 non-null uint8
# VERIFIED - income source    164309 non-null uint8
# not verified                164309 non-null uint8
# Female                      164309 non-null uint8
# Male                        164309 non-null uint8
# dtypes: float64(3), int64(6), object(3), uint8(5)
# memory usage: 15.8+ MB

# %%
loan_df['Purpose_Of_Loan'].value_counts()
# Out:
# debt_consolidation    97101
# credit_card           36684
# home_improvement       9269
# other                  8346
# major_purchase         3435
# small_business         2392
# car                    1885
# medical                1541
# moving                  974
# vacation                837
# wedding                 828
# house                   773
# renewable_energy        123
# educational             121
# Name: Purpose_Of_Loan, dtype: int64

# %%
dict_p = {'debt_consolidation':round(loan_df[loan_df['Purpose_Of_Loan']=='debt_consolidation'].shape[0]/loan_df.shape[0],3), 
          'credit_card':round(loan_df[loan_df['Purpose_Of_Loan']=='credit_card'].shape[0]/loan_df.shape[0],3),
         'home_improvement':round(loan_df[loan_df['Purpose_Of_Loan']=='home_improvement'].shape[0]/loan_df.shape[0],3),
         'other':round(loan_df[loan_df['Purpose_Of_Loan']=='other'].shape[0]/loan_df.shape[0],3),
         'major_purchase':round(loan_df[loan_df['Purpose_Of_Loan']=='major_purchase'].shape[0]/loan_df.shape[0],3),
         'small_business':round(loan_df[loan_df['Purpose_Of_Loan']=='small_business'].shape[0]/loan_df.shape[0],3),
         'car':round(loan_df[loan_df['Purpose_Of_Loan']=='car'].shape[0]/loan_df.shape[0],3),
         'medical':round(loan_df[loan_df['Purpose_Of_Loan']=='medical'].shape[0]/loan_df.shape[0],3),
         'moving':round(loan_df[loan_df['Purpose_Of_Loan']=='moving'].shape[0]/loan_df.shape[0],3),
         'vacation':round(loan_df[loan_df['Purpose_Of_Loan']=='vacation'].shape[0]/loan_df.shape[0],3),
         'wedding':round(loan_df[loan_df['Purpose_Of_Loan']=='wedding'].shape[0]/loan_df.shape[0],3),
         'house':round(loan_df[loan_df['Purpose_Of_Loan']=='house'].shape[0]/loan_df.shape[0],3),
         'renewable_energy':round(loan_df[loan_df['Purpose_Of_Loan']=='renewable_energy'].shape[0]/loan_df.shape[0],3),
         'educational':round(loan_df[loan_df['Purpose_Of_Loan']=='educational'].shape[0]/loan_df.shape[0],3)}

# %%
dict_p
# Out:
# {'debt_consolidation': 0.591,
#  'credit_card': 0.223,
#  'home_improvement': 0.056,
#  'other': 0.051,
#  'major_purchase': 0.021,
#  'small_business': 0.015,
#  'car': 0.011,
#  'medical': 0.009,
#  'moving': 0.006,
#  'vacation': 0.005,
#  'wedding': 0.005,
#  'house': 0.005,
#  'renewable_energy': 0.001,
#  'educational': 0.001}

# %%
loan_df['Purpose_Of_Loan_mod'] = loan_df['Purpose_Of_Loan'].apply(lambda x : dict_p.get(x))

# %%
loan_df.head(30)
# Out:
#      Loan_ID  Loan_Amount_Requested Length_Employed Home_Owner  Annual_Income  \
# 0   10000001                   7000        < 1 year       Rent        68000.0
# 1   10000002                  30000         4 years   Mortgage            NaN
# 2   10000003                  24725         7 years   Mortgage        75566.4
# 3   10000004                  16000        < 1 year        NaN        56160.0
# 4   10000005                  17000         8 years        Own        96000.0
# 5   10000006                   4500         2 years       Rent        30000.0
# 6   10000007                  18075         4 years       Rent        85000.0
# 7   10000008                  15000        < 1 year       Rent       115000.0
# 8   10000009                   6300       10+ years       Rent            NaN
# 9   10000010                  30000       10+ years        Own       163000.0
# 10  10000011                  11700       10+ years   Mortgage        62000.0
# 11  10000012                  15000       10+ years       Rent        70000.0
# 12  10000013                   7200       10+ years       Rent        55000.0
# 13  10000014                  15000       10+ years   Mortgage            NaN
# 14  10000015                   6700       10+ years   Mortgage        16000.0
# 15  10000016                  35000         4 years       Rent       101000.0
# 16  10000017                  20800       10+ years   Mortgage            NaN
# 17  10000018                  19925       10+ years       Rent        50000.0
# 18  10000019                  25000       10+ years       Rent        62000.0
# 19  10000020                   6000          1 year        Own        20000.0
# 20  10000021                   4000       10+ years       Rent        55000.0
# 21  10000022                   8000         7 years   Mortgage        55000.0
# 22  10000023                  12000       10+ years       Rent        48000.0
# 23  10000024                   9050             NaN   Mortgage        46500.0
# 24  10000025                  15000       10+ years   Mortgage            NaN
# 25  10000026                   2200         7 years   Mortgage        82000.0
# 26  10000027                  20000       10+ years   Mortgage       125000.0
# 27  10000028                  21700       10+ years   Mortgage            NaN
# 28  10000029                   8875         8 years        NaN        26500.0
# 29  10000030                  35000         6 years   Mortgage        82000.0
#
#        Purpose_Of_Loan  Debt_To_Income  Inquiries_Last_6Mo  \
# 0                  car           18.37                   0
# 1   debt_consolidation           14.93                   0
# 2   debt_consolidation           15.88                   0
# 3   debt_consolidation           14.34                   3
# 4   debt_consolidation           22.17                   1
# 5          credit_card           10.88                   1
# 6   debt_consolidation            5.65                   0
# 7   debt_consolidation            7.97                   1
# 8   debt_consolidation           16.12                   3
# 9   debt_consolidation           11.13                   0
# 10  debt_consolidation           30.91                   0
# 11         credit_card            8.95                   0
# 12  debt_consolidation           31.25                   0
# 13  debt_consolidation           21.03                   0
# 14         credit_card           14.70                   0
# 15         credit_card           15.24                   0
# 16  debt_consolidation           10.50                   1
# 17  debt_consolidation           37.28                   1
# 18         credit_card           13.72                   0
# 19  debt_consolidation           12.67                   2
# 20         credit_card           23.04                   0
# 21    home_improvement           19.33                   1
# 22  debt_consolidation           28.48                   2
# 23  debt_consolidation           30.43                   0
# 24  debt_consolidation           15.90                   0
# 25      major_purchase            5.02                   1
# 26  debt_consolidation            9.09                   4
# 27  debt_consolidation           16.82                   2
# 28  debt_consolidation           10.14                   0
# 29         credit_card            8.40                   0
#
#     Months_Since_Deliquency  Number_Open_Accounts  Total_Accounts  \
# 0                      12.0                     9              14
# 1                      17.0                    12              24
# 2                      47.0                    12              16
# 3                      48.0                    16              22
# 4                      26.0                    19              30
# 5                      38.0                    12              15
# 6                      23.0                     9              12
# 7                      16.0                    25              31
# 8                      54.0                     8               9
# 9                      14.0                    24              43
# 10                     59.0                     8              22
# 11                     41.0                     7              13
# 12                     68.0                     5              16
# 13                     10.0                     9              14
# 14                     13.0                    20              43
# 15                     49.0                    10              17
# 16                      6.0                     9              28
# 17                     20.0                    15              31
# 18                     64.0                     6              26
# 19                     23.0                     5              12
# 20                     10.0                    15              21
# 21                     10.0                    10              20
# 22                     63.0                    14              34
# 23                     33.0                     8              26
# 24                     37.0                    10              27
# 25                     22.0                    14              21
# 26                     13.0                    10              21
# 27                     33.0                    16              31
# 28                     30.0                     6              10
# 29                     18.0                     9               9
#
#     Interest_Rate  VERIFIED - income  VERIFIED - income source  not verified  \
# 0               1                  0                         0             1
# 1               3                  1                         0             0
# 2               3                  0                         1             0
# 3               3                  0                         1             0
# 4               1                  0                         1             0
# 5               3                  0                         1             0
# 6               3                  1                         0             0
# 7               2                  1                         0             0
# 8               3                  0                         0             1
# 9               1                  1                         0             0
# 10              2                  1                         0             0
# 11              2                  0                         0             1
# 12              2                  0                         1             0
# 13              2                  0                         1             0
# 14              2                  0                         1             0
# 15              3                  1                         0             0
# 16              3                  0                         1             0
# 17              2                  0                         1             0
# 18              3                  1                         0             0
# 19              3                  0                         1             0
# 20              1                  0                         0             1
# 21              3                  0                         0             1
# 22              3                  0                         0             1
# 23              3                  1                         0             0
# 24              3                  0                         0             1
# 25              1                  0                         0             1
# 26              3                  0                         1             0
# 27              2                  1                         0             0
# 28              2                  1                         0             0
# 29              2                  1                         0             0
#
#     Female  Male  Purpose_Of_Loan_mod
# 0        1     0                0.011
# 1        1     0                0.591
# 2        0     1                0.591
# 3        0     1                0.591
# 4        1     0                0.591
# 5        0     1                0.223
# 6        0     1                0.591
# 7        1     0                0.591
# 8        1     0                0.591
# 9        0     1                0.591
# 10       0     1                0.591
# 11       0     1                0.223
# 12       0     1                0.591
# 13       0     1                0.591
# 14       0     1                0.223
# 15       1     0                0.223
# 16       0     1                0.591
# 17       0     1                0.591
# 18       1     0                0.223
# 19       0     1                0.591
# 20       1     0                0.223
# 21       1     0                0.056
# 22       0     1                0.591
# 23       0     1                0.591
# 24       0     1                0.591
# 25       1     0                0.021
# 26       0     1                0.591
# 27       0     1                0.591
# 28       0     1                0.591
# 29       0     1                0.223

# %%
loan_df.drop('Purpose_Of_Loan', axis =1, inplace = True)

# %%
loan_df['Length_Employed'].value_counts()
# Out:
# 10+ years    52915
# 2 years      14620
# 3 years      12974
# < 1 year     12805
# 5 years      10814
# 1 year       10422
# 4 years       9784
# 7 years       9308
# 6 years       9094
# 8 years       7917
# 9 years       6285
# Name: Length_Employed, dtype: int64

# %%
dict_LE = {"10+ years":10,'9 years':9,'8 years':8,'7 years':7,'6 years':6,'5 years':5,'4 years':4,'3 years':3,'2 years':2,
           '1 year':1,'< 1 year':0}

# %%
loan_df['Length_Employed'] = loan_df['Length_Employed'].apply(lambda x : dict_LE.get(x))

# %%
loan_df.head(10)
# Out:
#     Loan_ID  Loan_Amount_Requested  Length_Employed Home_Owner  Annual_Income  \
# 0  10000001                   7000              0.0       Rent        68000.0
# 1  10000002                  30000              4.0   Mortgage            NaN
# 2  10000003                  24725              7.0   Mortgage        75566.4
# 3  10000004                  16000              0.0        NaN        56160.0
# 4  10000005                  17000              8.0        Own        96000.0
# 5  10000006                   4500              2.0       Rent        30000.0
# 6  10000007                  18075              4.0       Rent        85000.0
# 7  10000008                  15000              0.0       Rent       115000.0
# 8  10000009                   6300             10.0       Rent            NaN
# 9  10000010                  30000             10.0        Own       163000.0
#
#    Debt_To_Income  Inquiries_Last_6Mo  Months_Since_Deliquency  \
# 0           18.37                   0                     12.0
# 1           14.93                   0                     17.0
# 2           15.88                   0                     47.0
# 3           14.34                   3                     48.0
# 4           22.17                   1                     26.0
# 5           10.88                   1                     38.0
# 6            5.65                   0                     23.0
# 7            7.97                   1                     16.0
# 8           16.12                   3                     54.0
# 9           11.13                   0                     14.0
#
#    Number_Open_Accounts  Total_Accounts  Interest_Rate  VERIFIED - income  \
# 0                     9              14              1                  0
# 1                    12              24              3                  1
# 2                    12              16              3                  0
# 3                    16              22              3                  0
# 4                    19              30              1                  0
# 5                    12              15              3                  0
# 6                     9              12              3                  1
# 7                    25              31              2                  1
# 8                     8               9              3                  0
# 9                    24              43              1                  1
#
#    VERIFIED - income source  not verified  Female  Male  Purpose_Of_Loan_mod
# 0                         0             1       1     0                0.011
# 1                         0             0       1     0                0.591
# 2                         1             0       0     1                0.591
# 3                         1             0       0     1                0.591
# 4                         1             0       1     0                0.591
# 5                         1             0       0     1                0.223
# 6                         0             0       0     1                0.591
# 7                         0             0       1     0                0.591
# 8                         0             1       1     0                0.591
# 9                         0             0       0     1                0.591

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164309 entries, 0 to 164308
# Data columns (total 17 columns):
# Loan_ID                     164309 non-null int64
# Loan_Amount_Requested       164309 non-null int64
# Length_Employed             156938 non-null float64
# Home_Owner                  138960 non-null object
# Annual_Income               139207 non-null float64
# Debt_To_Income              164309 non-null float64
# Inquiries_Last_6Mo          164309 non-null int64
# Months_Since_Deliquency     164309 non-null float64
# Number_Open_Accounts        164309 non-null int64
# Total_Accounts              164309 non-null int64
# Interest_Rate               164309 non-null int64
# VERIFIED - income           164309 non-null uint8
# VERIFIED - income source    164309 non-null uint8
# not verified                164309 non-null uint8
# Female                      164309 non-null uint8
# Male                        164309 non-null uint8
# Purpose_Of_Loan_mod         164309 non-null float64
# dtypes: float64(5), int64(6), object(1), uint8(5)
# memory usage: 15.8+ MB

# %%
loan_df['Length_Employed'].value_counts()
# Out:
# 10.0    52915
# 2.0     14620
# 3.0     12974
# 0.0     12805
# 5.0     10814
# 1.0     10422
# 4.0      9784
# 7.0      9308
# 6.0      9094
# 8.0      7917
# 9.0      6285
# Name: Length_Employed, dtype: int64

# %%
def encode_Home_Owner(x):
    if 'Mortgage' in x:
        return 1
    elif 'Rent' in x:
        return 2
    elif 'Own' in x:
        return 3
    elif 'Other' in x:
        return 4
    else:
        return x

# %%
loan_df['Home_Owner'] = loan_df['Home_Owner'].dropna().apply(lambda x : encode_Home_Owner(x) if(np.all(pd.notnull(x[1]))) else x)

# %%
loan_df.head(20)
# Out:
#      Loan_ID  Loan_Amount_Requested  Length_Employed Home_Owner  \
# 0   10000001                   7000              0.0          2
# 1   10000002                  30000              4.0          1
# 2   10000003                  24725              7.0          1
# 3   10000004                  16000              0.0        NaN
# 4   10000005                  17000              8.0          3
# 5   10000006                   4500              2.0          2
# 6   10000007                  18075              4.0          2
# 7   10000008                  15000              0.0          2
# 8   10000009                   6300             10.0          2
# 9   10000010                  30000             10.0          3
# 10  10000011                  11700             10.0          1
# 11  10000012                  15000             10.0          2
# 12  10000013                   7200             10.0          2
# 13  10000014                  15000             10.0          1
# 14  10000015                   6700             10.0          1
# 15  10000016                  35000              4.0          2
# 16  10000017                  20800             10.0          1
# 17  10000018                  19925             10.0          2
# 18  10000019                  25000             10.0          2
# 19  10000020                   6000              1.0          3
#
#     Annual_Income  Debt_To_Income  Inquiries_Last_6Mo  \
# 0         68000.0           18.37                   0
# 1             NaN           14.93                   0
# 2         75566.4           15.88                   0
# 3         56160.0           14.34                   3
# 4         96000.0           22.17                   1
# 5         30000.0           10.88                   1
# 6         85000.0            5.65                   0
# 7        115000.0            7.97                   1
# 8             NaN           16.12                   3
# 9        163000.0           11.13                   0
# 10        62000.0           30.91                   0
# 11        70000.0            8.95                   0
# 12        55000.0           31.25                   0
# 13            NaN           21.03                   0
# 14        16000.0           14.70                   0
# 15       101000.0           15.24                   0
# 16            NaN           10.50                   1
# 17        50000.0           37.28                   1
# 18        62000.0           13.72                   0
# 19        20000.0           12.67                   2
#
#     Months_Since_Deliquency  Number_Open_Accounts  Total_Accounts  \
# 0                      12.0                     9              14
# 1                      17.0                    12              24
# 2                      47.0                    12              16
# 3                      48.0                    16              22
# 4                      26.0                    19              30
# 5                      38.0                    12              15
# 6                      23.0                     9              12
# 7                      16.0                    25              31
# 8                      54.0                     8               9
# 9                      14.0                    24              43
# 10                     59.0                     8              22
# 11                     41.0                     7              13
# 12                     68.0                     5              16
# 13                     10.0                     9              14
# 14                     13.0                    20              43
# 15                     49.0                    10              17
# 16                      6.0                     9              28
# 17                     20.0                    15              31
# 18                     64.0                     6              26
# 19                     23.0                     5              12
#
#     Interest_Rate  VERIFIED - income  VERIFIED - income source  not verified  \
# 0               1                  0                         0             1
# 1               3                  1                         0             0
# 2               3                  0                         1             0
# 3               3                  0                         1             0
# 4               1                  0                         1             0
# 5               3                  0                         1             0
# 6               3                  1                         0             0
# 7               2                  1                         0             0
# 8               3                  0                         0             1
# 9               1                  1                         0             0
# 10              2                  1                         0             0
# 11              2                  0                         0             1
# 12              2                  0                         1             0
# 13              2                  0                         1             0
# 14              2                  0                         1             0
# 15              3                  1                         0             0
# 16              3                  0                         1             0
# 17              2                  0                         1             0
# 18              3                  1                         0             0
# 19              3                  0                         1             0
#
#     Female  Male  Purpose_Of_Loan_mod
# 0        1     0                0.011
# 1        1     0                0.591
# 2        0     1                0.591
# 3        0     1                0.591
# 4        1     0                0.591
# 5        0     1                0.223
# 6        0     1                0.591
# 7        1     0                0.591
# 8        1     0                0.591
# 9        0     1                0.591
# 10       0     1                0.591
# 11       0     1                0.223
# 12       0     1                0.591
# 13       0     1                0.591
# 14       0     1                0.223
# 15       1     0                0.223
# 16       0     1                0.591
# 17       0     1                0.591
# 18       1     0                0.223
# 19       0     1                0.591

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164309 entries, 0 to 164308
# Data columns (total 17 columns):
# Loan_ID                     164309 non-null int64
# Loan_Amount_Requested       164309 non-null int64
# Length_Employed             156938 non-null float64
# Home_Owner                  138960 non-null object
# Annual_Income               139207 non-null float64
# Debt_To_Income              164309 non-null float64
# Inquiries_Last_6Mo          164309 non-null int64
# Months_Since_Deliquency     164309 non-null float64
# Number_Open_Accounts        164309 non-null int64
# Total_Accounts              164309 non-null int64
# Interest_Rate               164309 non-null int64
# VERIFIED - income           164309 non-null uint8
# VERIFIED - income source    164309 non-null uint8
# not verified                164309 non-null uint8
# Female                      164309 non-null uint8
# Male                        164309 non-null uint8
# Purpose_Of_Loan_mod         164309 non-null float64
# dtypes: float64(5), int64(6), object(1), uint8(5)
# memory usage: 15.8+ MB

# %%
corr = loan_df.corr()
